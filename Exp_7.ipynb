# %% [markdown]
# Summarize long texts using a pre-trained summarization model using Hugging
# Face model. Load the summarization pipeline. Take a passage as input and obtain the
# summarized text.

# %%
from transformers import pipeline

# Load summarization model explicitly
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")

text = """
Artificial Intelligence (AI) is a rapidly evolving field focused on creating intelligent machines.
It has impacted industries like healthcare, finance, and education. AI applications include chatbots,
self-driving cars, and recommendation systems. However, it also raises ethical concerns like bias
and job displacement.
"""

summary = summarizer(text, max_length=60, min_length=20, do_sample=False)

print("Summary:\n", summary[0]['summary_text'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 4
#       1 from transformers import pipeline
#       2
#       3 # Load summarization model explicitly
# ----> 4 summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
#       5
#       6 text = """
#       7 Artificial Intelligence (AI) is a rapidly evolving field focused on creating intelligent machines.
#
# File ~/Documents/6th sem/NLP/NLP_LAB/.venv/lib/python3.13/site-packages/transformers/pipelines/__init__.py:943, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     936         pipeline_class = get_class_from_dynamic_module(
#     937             class_ref,
#     938             model,
#     939             code_revision=code_revision,
#     940             **hub_kwargs,
#     941         )
#     942 else:
# --> 943     normalized_task, targeted_task, task_options = check_task(task)
#     944     if pipeline_class is None:
#     945         pipeline_class = targeted_task["impl"]
#
# File ~/Documents/6th sem/NLP/NLP_LAB/.venv/lib/python3.13/site-packages/transformers/pipelines/__init__.py:355, in check_task(task)
#     319 def check_task(task: str) -> tuple[str, dict, Any]:
#     320     """
#     321     Checks an incoming task string, to validate it's correct and return the default Pipeline and Model classes, and
#     322     default models if they exist.
#    (...)    353
#     354     """
# --> 355     return PIPELINE_REGISTRY.check_task(task)
#
# File ~/Documents/6th sem/NLP/NLP_LAB/.venv/lib/python3.13/site-packages/transformers/pipelines/base.py:1340, in PipelineRegistry.check_task(self, task)
#    1337     targeted_task = self.supported_tasks[task]
#    1338     return task, targeted_task, None
# -> 1340 raise KeyError(f"Unknown task {task}, available tasks are {self.get_supported_tasks()}")
#
# KeyError: "Unknown task summarization, available tasks are ['any-to-any', 'audio-classification', 'automatic-speech-recognition', 'depth-estimation', 'document-question-answering', 'feature-extraction', 'fill-mask', 'image-classification', 'image-feature-extraction', 'image-segmentation', 'image-text-to-text', 'keypoint-matching', 'mask-generation', 'ner', 'object-detection', 'sentiment-analysis', 'table-question-answering', 'text-classification', 'text-generation', 'text-to-audio', 'text-to-speech', 'token-classification', 'video-classification', 'zero-shot-audio-classification', 'zero-shot-classification', 'zero-shot-image-classification', 'zero-shot-object-detection']"

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

text = """
Summarize this:
Artificial Intelligence (AI) is a rapidly evolving field focused on creating intelligent machines.
It has impacted industries like healthcare, finance, and education. AI applications include chatbots,
self-driving cars, and recommendation systems. However, it also raises ethical concerns like bias
and job displacement.
"""

output = generator(text, max_length=100, num_return_sequences=1)

print(output[0]['generated_text'])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'num_return_sequences', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Summarize this:
# Artificial Intelligence (AI) is a rapidly evolving field focused on creating intelligent machines.
# It has impacted industries like healthcare, finance, and education. AI applications include chatbots,
# self-driving cars, and recommendation systems. However, it also raises ethical concerns like bias
# and job displacement.
# AI has created a new breed of tech, one that can make people more open to the idea of autonomous, non-judgmental, and self-driving cars.
# Artificial Intelligence
# Artificial Intelligence (AI) is a rapidly evolving field focused on creating intelligent machines.
# Its applications include chatbots, voice recognition, social networking, and social media. However, it also raises ethical concerns like bias and job displacement.
# Artificial Intelligence (AI) has created a new breed of tech, one that can make people more open to the idea of autonomous, non-judgmental, and self-driving cars.
# Artificial Intelligence (AI) has produced new technologies like smart phone and AI, and it has also created new technologies like self-driving cars.
# Artificial Intelligence (AI) is the latest of a growing number of technologies in which AI has been used for the goal of self-driving cars.
# Artificial human intelligence is being used throughout the world to better understand human behavior.
# Artificial intelligence is being used across the world to better understand human behavior.
# Artificial intelligence is being used to better understand human behavior.
# Artificial intelligence is being used to better see and respond to questions in our everyday lives.
# Artificial intelligence
