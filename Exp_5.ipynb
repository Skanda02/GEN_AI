# %% [markdown]
#  Use word embeddings to create meaningful sentences for creative tasks. Retrieve
# similar words for a seed word. Create a sentence or story using these words as a starting
# point. Write a program that: Takes a seed word. Generates similar words. Constructs a short
# paragraph using these words.

# %%
import gensim.downloader as api

# Load model
model = api.load("glove-wiki-gigaword-50")

# Input seed word
seed = input("Enter a word: ")

# Get similar words
similar = [w[0] for w in model.most_similar(seed, topn=5)]

# Create paragraph
paragraph = f"""
The {seed} was known for its connection with {similar[0]} and {similar[1]}.
People often related it to {similar[2]} and {similar[3]}.
In many stories, {similar[4]} played an important role alongside the {seed}.
"""

print("\nGenerated Paragraph:\n")
print(paragraph)
# Out:
# Generated Paragraph:
#
#
# The travel was known for its connection with trips and travelers.
# People often related it to traveling and destinations.
# In many stories, flights played an important role alongside the travel.
